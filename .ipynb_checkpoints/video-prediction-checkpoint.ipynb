# %% [markdown]
# # COS 470 - Image Processing and Computer Vision
#
# #  Sports Image Classification -- Video Prediction
# ### Authors: Ethan Gilles, Josh Thyng, Sam Fickett
#
# ---
#
# ## Setup

# %%
import os
import sys
import math
import torch
import torchvision
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt

import torch.nn as nn
import torch.nn.functional as F

from torchvision.utils import make_grid
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import torch.optim as optim
from torchinfo import summary

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.device(device)

class SportsNet(nn.Module):
    def __init__(self):
        super(SportsNet, self).__init__()
        self.model = nn.Sequential(
            # First Convolutional Layer
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),  # Batch normalization for 96 channels
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Second Convolutional Layer
            nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),  # Batch normalization for 256 channels
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Third Convolutional Layer
            nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),  # Batch normalization for 384 channels
            nn.ReLU(),


            # Fourth Convolutional Layer
            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),  # Batch normalization for 384 channels
            nn.ReLU(),


            # Fifth Convolutional Layer
            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),  # Batch normalization for 256 channels
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Flatten and Fully Connected Layers
            nn.Flatten(),
            nn.Linear(in_features=6400, out_features=4096),
            nn.BatchNorm1d(4096),  # Batch normalization for fully connected layer
            nn.ReLU(),
            nn.Dropout(),

            nn.Linear(in_features=4096, out_features=2048),
            nn.BatchNorm1d(2048),  # Batch normalization for fully connected layer
            nn.ReLU(),
            nn.Dropout(),

            nn.Linear(in_features=2048, out_features=100),  # Output layer
        )

    def forward(self, x):
        return self.model(x)

# Create model instance
model = SportsNet().to(device)

img_transforms  = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.25), # 25% chance for horizontal flip
    transforms.RandomVerticalFlip(p=0.25),   # 25% change for vertical flip
    transforms.RandomRotation(degrees=45),   # Rotates to a random angle between -45 and 45 degrees
    transforms.ToTensor(),                   # Makes it a PyTorch Tensor

    # Normalization values reused from a source on Kaggle
    # other norm values could be used depending on accuracy:
    # Other Source -> mean=[-0.0932, -0.0971, -0.1260], std=[0.5091, 0.4912, 0.4931]
    # ImageNet -> mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]

    
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Use image folder to load the images and apply transforms
test_data = ImageFolder(root='test', transform=img_transforms)
test_dataloader = DataLoader(dataset=test_data, batch_size=64, shuffle=False, num_workers=2)

# %% [markdown]
# ## Test on video file

# %%
import cv2
class_names = test_dataloader.dataset.classes
model = SportsNet()
model.load_state_dict(torch.load('SportsNet_weights.pth', weights_only=True))
model.eval()
model = model.to(device)


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

video_path = "Golf.mp4"
cap = cv2.VideoCapture(video_path)
frame_predictions = []  # Stores probabilities for all frames
frame_class_indices = []  # Stores predicted class indices for all frames
frame_predictions_with_indices = []  # Stores (frame_index, predicted_class_name)

with torch.no_grad():
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Process the frame (convert to tensor and normalize)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame_pil = Image.fromarray(frame_rgb)
        input_tensor = transform(frame_pil)
        input_batch = input_tensor.unsqueeze(0).to(device)

        # Get predictions from the model
        outputs = model(input_batch)
        probs = F.softmax(outputs, dim=1)

        # Append predictions and class index
        frame_predictions.append(probs.cpu().numpy()[0])
        predicted_class_idx = probs.argmax(dim=1).item()
        frame_class_indices.append(predicted_class_idx)

        predicted_class_name = class_names[predicted_class_idx]
        frame_predictions_with_indices.append((frame_count, predicted_class_name))

cap.release()

# Most common class prediction
most_common_class_idx = max(set(frame_class_indices), key=frame_class_indices.count)
predicted_class_name = class_names[most_common_class_idx]
count_most_common = frame_class_indices.count(most_common_class_idx)

print(f"The video is predicted to be: {predicted_class_name} chosen {count_most_common} times out of {len(frame_class_indices)} frames.")

# Individual frame predictions
print("\nIndividual Frame Predictions:")
for frame_idx, class_name in frame_predictions_with_indices:
    print(f"Frame {frame_idx}: Predicted class = {class_name}")
# Out:
# The video is predicted to be: golf chosen 343 times out of 417 frames.
#
# Individual Frame Predictions:
# Frame 1: Predicted class = frisbee
# Frame 2: Predicted class = frisbee
# Frame 3: Predicted class = frisbee
# Frame 4: Predicted class = frisbee
# Frame 5: Predicted class = frisbee
# Frame 6: Predicted class = frisbee
# Frame 7: Predicted class = frisbee
# Frame 8: Predicted class = frisbee
# Frame 9: Predicted class = frisbee
# Frame 10: Predicted class = frisbee
# Frame 11: Predicted class = frisbee
# Frame 12: Predicted class = frisbee
# Frame 13: Predicted class = frisbee
# Frame 14: Predicted class = frisbee
# Frame 15: Predicted class = frisbee
# Frame 16: Predicted class = frisbee
# Frame 17: Predicted class = frisbee
# Frame 18: Predicted class = frisbee
# Frame 19: Predicted class = frisbee
# Frame 20: Predicted class = frisbee
# Frame 21: Predicted class = frisbee
# Frame 22: Predicted class = frisbee
# Frame 23: Predicted class = frisbee
# Frame 24: Predicted class = ultimate
# Frame 25: Predicted class = ultimate
# Frame 26: Predicted class = ultimate
# Frame 27: Predicted class = ultimate
# Frame 28: Predicted class = ultimate
# Frame 29: Predicted class = ultimate
# Frame 30: Predicted class = ultimate
# Frame 31: Predicted class = ultimate
# Frame 32: Predicted class = ultimate
# Frame 33: Predicted class = ultimate
# Frame 34: Predicted class = ultimate
# Frame 35: Predicted class = golf
# Frame 36: Predicted class = golf
# Frame 37: Predicted class = golf
# Frame 38: Predicted class = golf
# Frame 39: Predicted class = golf
# Frame 40: Predicted class = golf
# Frame 41: Predicted class = golf
# Frame 42: Predicted class = golf
# Frame 43: Predicted class = golf
# Frame 44: Predicted class = golf
# Frame 45: Predicted class = golf
# Frame 46: Predicted class = golf
# Frame 47: Predicted class = golf
# Frame 48: Predicted class = golf
# Frame 49: Predicted class = golf
# Frame 50: Predicted class = golf
# Frame 51: Predicted class = golf
# Frame 52: Predicted class = golf
# Frame 53: Predicted class = golf
# Frame 54: Predicted class = golf
# Frame 55: Predicted class = golf
# Frame 56: Predicted class = golf
# Frame 57: Predicted class = golf
# Frame 58: Predicted class = golf
# Frame 59: Predicted class = golf
# Frame 60: Predicted class = golf
# Frame 61: Predicted class = golf
# Frame 62: Predicted class = golf
# Frame 63: Predicted class = golf
# Frame 64: Predicted class = golf
# Frame 65: Predicted class = golf
# Frame 66: Predicted class = golf
# Frame 67: Predicted class = golf
# Frame 68: Predicted class = golf
# Frame 69: Predicted class = golf
# Frame 70: Predicted class = golf
# Frame 71: Predicted class = golf
# Frame 72: Predicted class = golf
# Frame 73: Predicted class = golf
# Frame 74: Predicted class = golf
# Frame 75: Predicted class = golf
# Frame 76: Predicted class = golf
# Frame 77: Predicted class = golf
# Frame 78: Predicted class = golf
# Frame 79: Predicted class = golf
# Frame 80: Predicted class = golf
# Frame 81: Predicted class = golf
# Frame 82: Predicted class = golf
# Frame 83: Predicted class = golf
# Frame 84: Predicted class = golf
# Frame 85: Predicted class = golf
# Frame 86: Predicted class = golf
# Frame 87: Predicted class = golf
# Frame 88: Predicted class = golf
# Frame 89: Predicted class = golf
# Frame 90: Predicted class = golf
# Frame 91: Predicted class = golf
# Frame 92: Predicted class = golf
# Frame 93: Predicted class = golf
# Frame 94: Predicted class = golf
# Frame 95: Predicted class = golf
# Frame 96: Predicted class = golf
# Frame 97: Predicted class = golf
# Frame 98: Predicted class = golf
# Frame 99: Predicted class = golf
# Frame 100: Predicted class = golf
# Frame 101: Predicted class = golf
# Frame 102: Predicted class = golf
# Frame 103: Predicted class = golf
# Frame 104: Predicted class = golf
# Frame 105: Predicted class = golf
# Frame 106: Predicted class = golf
# Frame 107: Predicted class = golf
# Frame 108: Predicted class = golf
# Frame 109: Predicted class = golf
# Frame 110: Predicted class = golf
# Frame 111: Predicted class = golf
# Frame 112: Predicted class = golf
# Frame 113: Predicted class = golf
# Frame 114: Predicted class = golf
# Frame 115: Predicted class = golf
# Frame 116: Predicted class = golf
# Frame 117: Predicted class = golf
# Frame 118: Predicted class = golf
# Frame 119: Predicted class = golf
# Frame 120: Predicted class = golf
# Frame 121: Predicted class = golf
# Frame 122: Predicted class = golf
# Frame 123: Predicted class = golf
# Frame 124: Predicted class = golf
# Frame 125: Predicted class = golf
# Frame 126: Predicted class = golf
# Frame 127: Predicted class = golf
# Frame 128: Predicted class = golf
# Frame 129: Predicted class = golf
# Frame 130: Predicted class = golf
# Frame 131: Predicted class = golf
# Frame 132: Predicted class = golf
# Frame 133: Predicted class = golf
# Frame 134: Predicted class = golf
# Frame 135: Predicted class = golf
# Frame 136: Predicted class = golf
# Frame 137: Predicted class = golf
# Frame 138: Predicted class = golf
# Frame 139: Predicted class = golf
# Frame 140: Predicted class = golf
# Frame 141: Predicted class = golf
# Frame 142: Predicted class = golf
# Frame 143: Predicted class = golf
# Frame 144: Predicted class = golf
# Frame 145: Predicted class = golf
# Frame 146: Predicted class = golf
# Frame 147: Predicted class = golf
# Frame 148: Predicted class = golf
# Frame 149: Predicted class = golf
# Frame 150: Predicted class = golf
# Frame 151: Predicted class = golf
# Frame 152: Predicted class = golf
# Frame 153: Predicted class = golf
# Frame 154: Predicted class = golf
# Frame 155: Predicted class = golf
# Frame 156: Predicted class = golf
# Frame 157: Predicted class = golf
# Frame 158: Predicted class = golf
# Frame 159: Predicted class = golf
# Frame 160: Predicted class = golf
# Frame 161: Predicted class = golf
# Frame 162: Predicted class = golf
# Frame 163: Predicted class = golf
# Frame 164: Predicted class = golf
# Frame 165: Predicted class = golf
# Frame 166: Predicted class = golf
# Frame 167: Predicted class = golf
# Frame 168: Predicted class = golf
# Frame 169: Predicted class = golf
# Frame 170: Predicted class = golf
# Frame 171: Predicted class = golf
# Frame 172: Predicted class = golf
# Frame 173: Predicted class = golf
# Frame 174: Predicted class = golf
# Frame 175: Predicted class = golf
# Frame 176: Predicted class = golf
# Frame 177: Predicted class = golf
# Frame 178: Predicted class = golf
# Frame 179: Predicted class = golf
# Frame 180: Predicted class = golf
# Frame 181: Predicted class = golf
# Frame 182: Predicted class = golf
# Frame 183: Predicted class = golf
# Frame 184: Predicted class = golf
# Frame 185: Predicted class = golf
# Frame 186: Predicted class = golf
# Frame 187: Predicted class = golf
# Frame 188: Predicted class = golf
# Frame 189: Predicted class = golf
# Frame 190: Predicted class = golf
# Frame 191: Predicted class = golf
# Frame 192: Predicted class = golf
# Frame 193: Predicted class = golf
# Frame 194: Predicted class = golf
# Frame 195: Predicted class = golf
# Frame 196: Predicted class = golf
# Frame 197: Predicted class = golf
# Frame 198: Predicted class = golf
# Frame 199: Predicted class = golf
# Frame 200: Predicted class = golf
# Frame 201: Predicted class = golf
# Frame 202: Predicted class = golf
# Frame 203: Predicted class = golf
# Frame 204: Predicted class = golf
# Frame 205: Predicted class = golf
# Frame 206: Predicted class = golf
# Frame 207: Predicted class = golf
# Frame 208: Predicted class = golf
# Frame 209: Predicted class = golf
# Frame 210: Predicted class = golf
# Frame 211: Predicted class = golf
# Frame 212: Predicted class = golf
# Frame 213: Predicted class = golf
# Frame 214: Predicted class = golf
# Frame 215: Predicted class = golf
# Frame 216: Predicted class = golf
# Frame 217: Predicted class = golf
# Frame 218: Predicted class = golf
# Frame 219: Predicted class = golf
# Frame 220: Predicted class = golf
# Frame 221: Predicted class = golf
# Frame 222: Predicted class = golf
# Frame 223: Predicted class = golf
# Frame 224: Predicted class = golf
# Frame 225: Predicted class = golf
# Frame 226: Predicted class = golf
# Frame 227: Predicted class = golf
# Frame 228: Predicted class = golf
# Frame 229: Predicted class = golf
# Frame 230: Predicted class = golf
# Frame 231: Predicted class = golf
# Frame 232: Predicted class = golf
# Frame 233: Predicted class = golf
# Frame 234: Predicted class = golf
# Frame 235: Predicted class = golf
# Frame 236: Predicted class = golf
# Frame 237: Predicted class = golf
# Frame 238: Predicted class = golf
# Frame 239: Predicted class = golf
# Frame 240: Predicted class = golf
# Frame 241: Predicted class = golf
# Frame 242: Predicted class = golf
# Frame 243: Predicted class = golf
# Frame 244: Predicted class = golf
# Frame 245: Predicted class = golf
# Frame 246: Predicted class = golf
# Frame 247: Predicted class = golf
# Frame 248: Predicted class = golf
# Frame 249: Predicted class = golf
# Frame 250: Predicted class = golf
# Frame 251: Predicted class = golf
# Frame 252: Predicted class = golf
# Frame 253: Predicted class = golf
# Frame 254: Predicted class = golf
# Frame 255: Predicted class = golf
# Frame 256: Predicted class = golf
# Frame 257: Predicted class = golf
# Frame 258: Predicted class = golf
# Frame 259: Predicted class = golf
# Frame 260: Predicted class = golf
# Frame 261: Predicted class = golf
# Frame 262: Predicted class = golf
# Frame 263: Predicted class = golf
# Frame 264: Predicted class = golf
# Frame 265: Predicted class = golf
# Frame 266: Predicted class = golf
# Frame 267: Predicted class = croquet
# Frame 268: Predicted class = croquet
# Frame 269: Predicted class = croquet
# Frame 270: Predicted class = golf
# Frame 271: Predicted class = croquet
# Frame 272: Predicted class = golf
# Frame 273: Predicted class = croquet
# Frame 274: Predicted class = croquet
# Frame 275: Predicted class = croquet
# Frame 276: Predicted class = croquet
# Frame 277: Predicted class = golf
# Frame 278: Predicted class = golf
# Frame 279: Predicted class = golf
# Frame 280: Predicted class = golf
# Frame 281: Predicted class = golf
# Frame 282: Predicted class = croquet
# Frame 283: Predicted class = croquet
# Frame 284: Predicted class = golf
# Frame 285: Predicted class = croquet
# Frame 286: Predicted class = golf
# Frame 287: Predicted class = croquet
# Frame 288: Predicted class = frisbee
# Frame 289: Predicted class = frisbee
# Frame 290: Predicted class = frisbee
# Frame 291: Predicted class = frisbee
# Frame 292: Predicted class = frisbee
# Frame 293: Predicted class = frisbee
# Frame 294: Predicted class = frisbee
# Frame 295: Predicted class = frisbee
# Frame 296: Predicted class = frisbee
# Frame 297: Predicted class = frisbee
# Frame 298: Predicted class = frisbee
# Frame 299: Predicted class = frisbee
# Frame 300: Predicted class = frisbee
# Frame 301: Predicted class = frisbee
# Frame 302: Predicted class = frisbee
# Frame 303: Predicted class = frisbee
# Frame 304: Predicted class = golf
# Frame 305: Predicted class = golf
# Frame 306: Predicted class = golf
# Frame 307: Predicted class = croquet
# Frame 308: Predicted class = golf
# Frame 309: Predicted class = croquet
# Frame 310: Predicted class = croquet
# Frame 311: Predicted class = croquet
# Frame 312: Predicted class = croquet
# Frame 313: Predicted class = croquet
# Frame 314: Predicted class = croquet
# Frame 315: Predicted class = croquet
# Frame 316: Predicted class = croquet
# Frame 317: Predicted class = croquet
# Frame 318: Predicted class = golf
# Frame 319: Predicted class = golf
# Frame 320: Predicted class = golf
# Frame 321: Predicted class = golf
# Frame 322: Predicted class = golf
# Frame 323: Predicted class = golf
# Frame 324: Predicted class = golf
# Frame 325: Predicted class = golf
# Frame 326: Predicted class = golf
# Frame 327: Predicted class = frisbee
# Frame 328: Predicted class = golf
# Frame 329: Predicted class = golf
# Frame 330: Predicted class = golf
# Frame 331: Predicted class = golf
# Frame 332: Predicted class = golf
# Frame 333: Predicted class = golf
# Frame 334: Predicted class = golf
# Frame 335: Predicted class = golf
# Frame 336: Predicted class = frisbee
# Frame 337: Predicted class = golf
# Frame 338: Predicted class = golf
# Frame 339: Predicted class = golf
# Frame 340: Predicted class = golf
# Frame 341: Predicted class = golf
# Frame 342: Predicted class = golf
# Frame 343: Predicted class = golf
# Frame 344: Predicted class = golf
# Frame 345: Predicted class = golf
# Frame 346: Predicted class = golf
# Frame 347: Predicted class = golf
# Frame 348: Predicted class = golf
# Frame 349: Predicted class = golf
# Frame 350: Predicted class = golf
# Frame 351: Predicted class = golf
# Frame 352: Predicted class = golf
# Frame 353: Predicted class = golf
# Frame 354: Predicted class = golf
# Frame 355: Predicted class = golf
# Frame 356: Predicted class = golf
# Frame 357: Predicted class = golf
# Frame 358: Predicted class = golf
# Frame 359: Predicted class = golf
# Frame 360: Predicted class = golf
# Frame 361: Predicted class = golf
# Frame 362: Predicted class = golf
# Frame 363: Predicted class = golf
# Frame 364: Predicted class = golf
# Frame 365: Predicted class = golf
# Frame 366: Predicted class = golf
# Frame 367: Predicted class = golf
# Frame 368: Predicted class = golf
# Frame 369: Predicted class = golf
# Frame 370: Predicted class = golf
# Frame 371: Predicted class = golf
# Frame 372: Predicted class = golf
# Frame 373: Predicted class = golf
# Frame 374: Predicted class = golf
# Frame 375: Predicted class = golf
# Frame 376: Predicted class = golf
# Frame 377: Predicted class = golf
# Frame 378: Predicted class = golf
# Frame 379: Predicted class = golf
# Frame 380: Predicted class = golf
# Frame 381: Predicted class = golf
# Frame 382: Predicted class = golf
# Frame 383: Predicted class = golf
# Frame 384: Predicted class = golf
# Frame 385: Predicted class = golf
# Frame 386: Predicted class = golf
# Frame 387: Predicted class = golf
# Frame 388: Predicted class = golf
# Frame 389: Predicted class = golf
# Frame 390: Predicted class = golf
# Frame 391: Predicted class = golf
# Frame 392: Predicted class = golf
# Frame 393: Predicted class = golf
# Frame 394: Predicted class = golf
# Frame 395: Predicted class = golf
# Frame 396: Predicted class = golf
# Frame 397: Predicted class = golf
# Frame 398: Predicted class = golf
# Frame 399: Predicted class = golf
# Frame 400: Predicted class = golf
# Frame 401: Predicted class = golf
# Frame 402: Predicted class = golf
# Frame 403: Predicted class = golf
# Frame 404: Predicted class = golf
# Frame 405: Predicted class = golf
# Frame 406: Predicted class = golf
# Frame 407: Predicted class = golf
# Frame 408: Predicted class = golf
# Frame 409: Predicted class = golf
# Frame 410: Predicted class = golf
# Frame 411: Predicted class = golf
# Frame 412: Predicted class = golf
# Frame 413: Predicted class = golf
# Frame 414: Predicted class = golf
# Frame 415: Predicted class = golf
# Frame 416: Predicted class = golf
# Frame 417: Predicted class = golf
